# %% [markdown]
# <a href="https://colab.research.google.com/github/HasankaRajakaruna/Kaggle-Projects/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train = pd.read_csv('/content/drive/MyDrive/Dataset/dataset_gbpusd_train.csv')
test = pd.read_csv('/content/drive/MyDrive/Dataset/dataset_gbpusd_test.csv')

# %%
train.shape
# Out:
# (21715, 10)

# %%
train.head()
# Out:
#                   time  Unnamed: 0     open     high      low    close  \
# 0  2010-01-04 00:00:00           0  1.61210  1.61486  1.60852  1.61087
# 1  2010-01-04 04:00:00           1  1.61087  1.61090  1.60691  1.60850
# 2  2010-01-04 08:00:00           2  1.60851  1.62380  1.60554  1.61744
# 3  2010-01-04 12:00:00           3  1.61748  1.62245  1.61375  1.61656
# 4  2010-01-04 16:00:00           4  1.61651  1.61877  1.60822  1.60958
#
#    tick_volume  spread  real_volume  target
# 0         7471      24            0       2
# 1         5966      24            0       2
# 2        13700      24            0       2
# 3        12921      24            0       2
# 4        10789      23            0       2

# %%
test.shape
# Out:
# (384, 11)

# %%
test_num_rows = test.shape[0]
test_num_rows
# Out:
# 384

# %%
test.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                 time     open     high      low  \
# 0             0           0  2024-01-02 00:00:00  1.27205  1.27355  1.27173
# 1             1           1  2024-01-02 04:00:00  1.27210  1.27414  1.27100
# 2             2           2  2024-01-02 08:00:00  1.27370  1.27602  1.27174
# 3             3           3  2024-01-02 12:00:00  1.27176  1.27188  1.26217
# 4             4           4  2024-01-02 16:00:00  1.26291  1.26448  1.26108
#
#      close  tick_volume  spread  real_volume  target
# 0  1.27210         5319       0            0       2
# 1  1.27370         6880       0            0       2
# 2  1.27176        13263       0            0       2
# 3  1.26300        16548       0            0       2
# 4  1.26330        18454       0            0       2

# %%
dataset = pd.concat([train,test])

# %%
dataset.shape
# Out:
# (22099, 11)

# %%
dataset.tail()
# Out:
#                     time  Unnamed: 0     open     high      low    close  \
# 379  2024-03-29 04:00:00         379  1.26255  1.26309  1.26151  1.26221
# 380  2024-03-29 08:00:00         380  1.26221  1.26257  1.26160  1.26255
# 381  2024-03-29 12:00:00         381  1.26255  1.26361  1.26092  1.26318
# 382  2024-03-29 16:00:00         382  1.26318  1.26445  1.26281  1.26286
# 383  2024-03-29 20:00:00         383  1.26286  1.26287  1.26142  1.26217
#
#      tick_volume  spread  real_volume  target  Unnamed: 0.1
# 379         5187       0            0       2         379.0
# 380         4534       2            0       2         380.0
# 381         5156       0            0       2         381.0
# 382         3878       1            0       2         382.0
# 383         2043       6            0       2         383.0

# %%
# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# !tar -xzvf ta-lib-0.4.0-src.tar.gz
# %cd ta-lib
# !./configure --prefix=/usr
# !make
# !make install
# !pip install Ta-Lib

# %%
import talib as ta

# %%
def calculate_heikin_ashi(data):
    data["HA_Close"] = (data["open"] + data["high"] + data["low"] + data["close"]) / 4
    data["HA_Open"] = (data["open"].shift(1) + data["close"].shift(1)) / 2
    data["HA_High"] = data[["high", "close", "open"]].max(axis=1)
    data["HA_Low"] = data[["low", "close", "open"]].min(axis=1)

calculate_heikin_ashi(dataset)

# %%
dataset.head()
# Out:
#                   time  Unnamed: 0     open     high      low    close  \
# 0  2010-01-04 00:00:00           0  1.61210  1.61486  1.60852  1.61087
# 1  2010-01-04 04:00:00           1  1.61087  1.61090  1.60691  1.60850
# 2  2010-01-04 08:00:00           2  1.60851  1.62380  1.60554  1.61744
# 3  2010-01-04 12:00:00           3  1.61748  1.62245  1.61375  1.61656
# 4  2010-01-04 16:00:00           4  1.61651  1.61877  1.60822  1.60958
#
#    tick_volume  spread  real_volume  target  Unnamed: 0.1  HA_Close   HA_Open  \
# 0         7471      24            0       2           NaN  1.611588       NaN
# 1         5966      24            0       2           NaN  1.609295  1.611485
# 2        13700      24            0       2           NaN  1.613822  1.609685
# 3        12921      24            0       2           NaN  1.617560  1.612975
# 4        10789      23            0       2           NaN  1.613270  1.617020
#
#    HA_High   HA_Low
# 0  1.61486  1.60852
# 1  1.61090  1.60691
# 2  1.62380  1.60554
# 3  1.62245  1.61375
# 4  1.61877  1.60822

# %%
dataset = dataset[['HA_Open', 'HA_High', 'HA_Low','HA_Close','target']]

# %%
dataset.head()
# Out:
#     HA_Open  HA_High   HA_Low  HA_Close  target
# 0       NaN  1.61486  1.60852  1.611588       2
# 1  1.611485  1.61090  1.60691  1.609295       2
# 2  1.609685  1.62380  1.60554  1.613822       2
# 3  1.612975  1.62245  1.61375  1.617560       2
# 4  1.617020  1.61877  1.60822  1.613270       2

# %%
close_prices = dataset['HA_Close'].values
high_prices = dataset['HA_High'].values
low_prices = dataset['HA_Low'].values
open_prices = dataset['HA_Open'].values

# %%
#RSI indicator
rsi_period2 = 2
dataset['rsi2'] = ta.RSI(close_prices, timeperiod=rsi_period2)

rsi_period4 = 4
dataset['rsi4'] = ta.RSI(close_prices, timeperiod=rsi_period4)

rsi_period8 = 8
dataset['rsi8'] = ta.RSI(close_prices, timeperiod=rsi_period8)

rsi_period14 = 14
dataset['rsi14'] = ta.RSI(close_prices, timeperiod=rsi_period14)

rsi_period21 = 21
dataset['rsi21'] = ta.RSI(close_prices, timeperiod=rsi_period21)

# %%
#Stochastic indicator
fast_period5 = 5
k_period5 = 3
d_period5 = 3
dataset['stochastic_K5'], dataset['stochastic_D5'] = ta.STOCH(high_prices, low_prices, close_prices, fastk_period=fast_period5, slowk_period=k_period5, slowd_period=d_period5)

fast_period14 = 14
k_period14 = 3
d_period14 = 3
dataset['stochastic_K14'], dataset['stochastic_D14'] = ta.STOCH(high_prices, low_prices, close_prices, fastk_period=fast_period14, slowk_period=k_period14, slowd_period=d_period14)

fast_period21 = 21
k_period21 = 5
d_period21 = 5
dataset['stochastic_K21'], dataset['stochastic_D21'] = ta.STOCH(high_prices, low_prices, close_prices, fastk_period=fast_period21, slowk_period=k_period21, slowd_period=d_period21)

# %%
#MACD indicator
fast_period12 = 12
slow_period26 = 26
signal_period = 9
dataset['MACD12'], dataset['Signal12'], _ = ta.MACD(close_prices, fastperiod=fast_period12, slowperiod=slow_period26, signalperiod=signal_period)

# %%
#Bollinger bands indicator

bb_period20 = 20
bb_std = 2
dataset['bb_upper_band'],dataset['bb_middle_band'], dataset['bb_lower_band'] = ta.BBANDS(close_prices, timeperiod=bb_period20, nbdevup=bb_std, nbdevdn=bb_std)

# %%
#Ema indicator
ema_period5 = 5
dataset['EMA5'] = ta.EMA(close_prices, timeperiod=ema_period5)

ema_period10 = 10
dataset['EMA10'] = ta.EMA(close_prices, timeperiod=ema_period10)

ema_period20 = 20
dataset['EMA20'] = ta.EMA(close_prices, timeperiod=ema_period20)

ema_period50 = 50
dataset['EMA50'] = ta.EMA(close_prices, timeperiod=ema_period50)

ema_period100 = 100
dataset['EMA100'] = ta.EMA(close_prices, timeperiod=ema_period100)

ema_period200 = 200
dataset['EMA200'] = ta.EMA(close_prices, timeperiod=ema_period200)

# %%
duplicates = dataset[dataset.duplicated()]

print("Duplicate Rows:")
print(duplicates)
# Out:
# Duplicate Rows:
# Empty DataFrame
# Columns: [HA_Open, HA_High, HA_Low, HA_Close, target, rsi2, rsi4, rsi8, rsi14, rsi21, stochastic_K5, stochastic_D5, stochastic_K14, stochastic_D14, stochastic_K21, stochastic_D21, MACD12, Signal12, bb_upper_band, bb_middle_band, bb_lower_band, EMA5, EMA10, EMA20, EMA50, EMA100, EMA200]
# Index: []
#
# [0 rows x 27 columns]

# %%
dataset.drop_duplicates(inplace=True)

# %%
missing_values = dataset.isnull().sum()

print("Columns with Missing Values:")
print(missing_values[missing_values > 0])
# Out:
# Columns with Missing Values:
# HA_Open             1
# rsi2                2
# rsi4                4
# rsi8                8
# rsi14              14
# rsi21              21
# stochastic_K5       8
# stochastic_D5       8
# stochastic_K14     17
# stochastic_D14     17
# stochastic_K21     28
# stochastic_D21     28
# MACD12             33
# Signal12           33
# bb_upper_band      19
# bb_middle_band     19
# bb_lower_band      19
# EMA5                4
# EMA10               9
# EMA20              19
# EMA50              49
# EMA100             99
# EMA200            199
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset.head()
# Out:
#       HA_Open  HA_High   HA_Low  HA_Close  target      rsi2       rsi4  \
# 199  1.566470  1.56809  1.56472  1.566120       2  1.542981  16.805586
# 200  1.565835  1.56695  1.55741  1.563025       2  0.476429  10.896671
# 201  1.563870  1.56732  1.55560  1.562138       2  0.341178   9.605404
# 202  1.562815  1.56580  1.55576  1.562115       2  0.336337   9.567081
# 203  1.563450  1.56327  1.54732  1.555213       2  0.034651   3.635005
#
#           rsi8      rsi14      rsi21  ...  Signal12  bb_upper_band  \
# 199  35.301069  43.420325  44.995246  ...  0.001393       1.579248
# 200  29.128932  39.098356  42.026198  ...  0.001123       1.579461
# 201  27.550324  37.932377  41.207500  ...  0.000792       1.579701
# 202  27.507133  37.901517  41.186142  ...  0.000436       1.579922
# 203  17.750489  29.872564  35.293733  ... -0.000026       1.581032
#
#      bb_middle_band  bb_lower_band      EMA5     EMA10     EMA20     EMA50  \
# 199        1.570082       1.560916  1.569004  1.570448  1.570089  1.571661
# 200        1.569913       1.560364  1.567011  1.569098  1.569416  1.571323
# 201        1.569752       1.559804  1.565386  1.567833  1.568723  1.570962
# 202        1.569585       1.559249  1.564296  1.566793  1.568093  1.570615
# 203        1.568949       1.556866  1.561268  1.564687  1.566867  1.570011
#
#        EMA100    EMA200
# 199  1.580173  1.599697
# 200  1.579833  1.599332
# 201  1.579483  1.598962
# 202  1.579139  1.598595
# 203  1.578665  1.598164
#
# [5 rows x 27 columns]

# %%
def calculate_target(data):

  for a in range(len(data)):

    for b in range(a,a+3,1):

      if b<len(data):
        #buy order
        diff_buy = abs((data['HA_Open'].iloc[a] - data['HA_High'].iloc[b])*10000)
        buy_order = False

        if diff_buy>= 30:
          buy_order = True

        #sell order
        diff_sell = abs((data['HA_Open'].iloc[a] - data['HA_Low'].iloc[b])*10000)
        sell_order = False

        if diff_sell>= 15:
          sell_order = True

        if sell_order and buy_order:
          data.loc[a, 'target'] = 2
          break
        elif buy_order:
          data.loc[a, 'target'] = 1
          break
        elif sell_order:
          data.loc[a, 'target'] = 0
          break
      else:
        break
calculate_target(dataset)

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import joblib
from sklearn.metrics import accuracy_score

# %%
test_data = dataset.tail(test_num_rows)
train_num_rows = dataset.shape[0]
train_data = dataset.head(train_num_rows-test_num_rows)

# %%
value_counts = train_data['target'].value_counts()
value_counts
# Out:
# target
# 0.0    11921
# 1.0     5294
# 2.0     4437
# Name: count, dtype: int64

# %%
#buy orders
bb_order = train_data[train_data['target'] == 1].tail(5000)
bb_order
# Out:
#        HA_Open  HA_High   HA_Low  HA_Close  target       rsi2       rsi4  \
# 1489  1.555135  1.55686  1.55408  1.555685     1.0  13.684036   7.741809
# 1490  1.555900  1.56131  1.55552  1.557912     1.0  66.462045  29.460441
# 1495  1.563695  1.56460  1.56137  1.563362     1.0  96.340038  68.541200
# 1504  1.555370  1.55354  1.54804  1.551752     1.0  25.481837  34.812373
# 1505  1.552715  1.55310  1.55005  1.551382     1.0  22.114760  33.011312
# ...        ...      ...      ...       ...     ...        ...        ...
# 95    1.268295  1.26918  1.26570  1.267325     1.0   5.858399  19.383326
# 100   1.276580  1.27750  1.27341  1.275602     1.0  89.710162  79.591569
# 116   1.270125  1.27190  1.26986  1.270585     1.0  56.032184  45.218797
# 134   1.267370  1.26742  1.26424  1.266012     1.0  14.644271  28.322636
# 135   1.266195  1.26858  1.26253  1.265653     1.0  11.961641  26.292444
#
#            rsi8      rsi14      rsi21  ...  Signal12  bb_upper_band  \
# 1489  16.092330  25.731097  32.253280  ... -0.002185       1.595102
# 1490  25.009594  30.353224  35.198552  ... -0.002865       1.595061
# 1495  45.327699  41.274016  42.216190  ... -0.004328       1.590652
# 1504  34.261189  34.544563  36.441748  ... -0.005159       1.566439
# 1505  33.486495  34.125728  36.151592  ... -0.005154       1.565098
# ...         ...        ...        ...  ...       ...            ...
# 95    33.740599  41.368928  44.313965  ...  0.000506       1.273773
# 100   69.609209  63.797311  60.003288  ...  0.000559       1.275788
# 116   46.326379  48.339599  49.296485  ...  0.000221       1.275367
# 134   36.181270  40.230732  42.724335  ... -0.000562       1.271875
# 135   34.883450  39.378207  42.111155  ... -0.000632       1.271938
#
#       bb_middle_band  bb_lower_band      EMA5     EMA10     EMA20     EMA50  \
# 1489        1.574367       1.553631  1.559255  1.564918  1.570439  1.573402
# 1490        1.573287       1.551512  1.558807  1.563644  1.569246  1.572794
# 1495        1.568858       1.547064  1.561968  1.562656  1.566349  1.570795
# 1504        1.557196       1.547952  1.553288  1.554825  1.558738  1.565638
# 1505        1.556465       1.547831  1.552653  1.554199  1.558038  1.565079
# ...              ...            ...       ...       ...       ...       ...
# 95          1.270108       1.266442  1.269591  1.270201  1.270028  1.269960
# 100         1.270950       1.266111  1.273467  1.272201  1.271185  1.270461
# 116         1.271784       1.268202  1.270691  1.270993  1.271131  1.270828
# 134         1.268979       1.266083  1.267723  1.268329  1.268969  1.269743
# 135         1.268755       1.265572  1.267033  1.267842  1.268653  1.269582
#
#         EMA100    EMA200
# 1489  1.575935  1.579863
# 1490  1.575578  1.579645
# 1495  1.574259  1.578770
# 1504  1.570892  1.576626
# 1505  1.570506  1.576375
# ...        ...       ...
# 95    1.269622  1.265996
# 100   1.269909  1.266318
# 116   1.270284  1.267055
# 134   1.269827  1.267342
# 135   1.269744  1.267325
#
# [5000 rows x 27 columns]

# %%
#sell orders
ss_order = train_data[train_data['target'] == 0].tail(5000)

# %%
new_dataset = pd.concat([bb_order, ss_order], ignore_index=True)
new_dataset
# Out:
#        HA_Open  HA_High   HA_Low  HA_Close  target       rsi2       rsi4  \
# 0     1.555135  1.55686  1.55408  1.555685     1.0  13.684036   7.741809
# 1     1.555900  1.56131  1.55552  1.557912     1.0  66.462045  29.460441
# 2     1.563695  1.56460  1.56137  1.563362     1.0  96.340038  68.541200
# 3     1.555370  1.55354  1.54804  1.551752     1.0  25.481837  34.812373
# 4     1.552715  1.55310  1.55005  1.551382     1.0  22.114760  33.011312
# ...        ...      ...      ...       ...     ...        ...        ...
# 9995  1.268965  1.26845  1.26730  1.267990     0.0  29.519068  38.023424
# 9996  1.268105  1.26973  1.26669  1.267795     0.0  23.887578  35.512466
# 9997  1.268770  1.27508  1.27005  1.271880     0.0  94.877367  80.432734
# 9998  1.271195  1.27393  1.26582  1.270055     0.0  48.373769  55.681453
# 9999  1.270235  1.26881  1.26630  1.267345     0.0  19.698877  34.600435
#
#            rsi8      rsi14      rsi21  ...  Signal12  bb_upper_band  \
# 0     16.092330  25.731097  32.253280  ... -0.002185       1.595102
# 1     25.009594  30.353224  35.198552  ... -0.002865       1.595061
# 2     45.327699  41.274016  42.216190  ... -0.004328       1.590652
# 3     34.261189  34.544563  36.441748  ... -0.005159       1.566439
# 4     33.486495  34.125728  36.151592  ... -0.005154       1.565098
# ...         ...        ...        ...  ...       ...            ...
# 9995  40.467210  43.195378  45.177805  ... -0.000505       1.273025
# 9996  39.358765  42.585447  44.774940  ... -0.000559       1.273024
# 9997  64.836005  57.042291  54.106960  ... -0.000558       1.273110
# 9998  53.061899  50.772238  50.085769  ... -0.000514       1.272501
# 9999  40.561496  43.181812  44.884668  ... -0.000508       1.271900
#
#       bb_middle_band  bb_lower_band      EMA5     EMA10     EMA20     EMA50  \
# 0           1.574367       1.553631  1.559255  1.564918  1.570439  1.573402
# 1           1.573287       1.551512  1.558807  1.563644  1.569246  1.572794
# 2           1.568858       1.547064  1.561968  1.562656  1.566349  1.570795
# 3           1.557196       1.547952  1.553288  1.554825  1.558738  1.565638
# 4           1.556465       1.547831  1.552653  1.554199  1.558038  1.565079
# ...              ...            ...       ...       ...       ...       ...
# 9995        1.269923       1.266821  1.268475  1.268921  1.269593  1.270153
# 9996        1.269796       1.266567  1.268248  1.268716  1.269422  1.270061
# 9997        1.269770       1.266429  1.269600  1.269316  1.269609  1.270088
# 9998        1.269602       1.266702  1.269751  1.269451  1.269652  1.270087
# 9999        1.269315       1.266730  1.268949  1.269068  1.269432  1.269979
#
#         EMA100    EMA200
# 0     1.575935  1.579863
# 1     1.575578  1.579645
# 2     1.574259  1.578770
# 3     1.570892  1.576626
# 4     1.570506  1.576375
# ...        ...       ...
# 9995  1.270025  1.267256
# 9996  1.269980  1.267262
# 9997  1.269997  1.267324
# 9998  1.269998  1.267351
# 9999  1.269945  1.267351
#
# [10000 rows x 27 columns]

# %%
X_data=new_dataset.drop(['target'],axis=1)
y_data=new_dataset[['target']]

# %%
scale = MinMaxScaler()
data_set_scaled = scale.fit_transform(X_data)
print(data_set_scaled)
# Out:
# [[0.75383023 0.75511725 0.76151526 ... 0.77391258 0.77538163 0.78496063]
#  [0.75499471 0.76188449 0.76363369 ... 0.77291942 0.77477831 0.78457909]
#  [0.76686024 0.76688768 0.77223979 ... 0.76964991 0.77254936 0.78305053]
#  ...
#  [0.31792616 0.32660665 0.34367047 ... 0.27797918 0.25817477 0.23899325]
#  [0.32161749 0.32485781 0.33744759 ... 0.27797708 0.25817672 0.23904073]
#  [0.32015618 0.31707169 0.33815373 ... 0.27780129 0.25808791 0.23904063]]

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.ensemble import RandomForestClassifier

X_train, X_test, y_train, y_test = train_test_split(data_set_scaled, y_data, test_size=0.2, random_state=42)
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
cv_scores = cross_val_score(rf_classifier, X_train, y_train, cv=5)  # 5-fold cross-validation
rf_classifier.fit(X_train, y_train)
test_score = rf_classifier.score(X_test, y_test)


print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", np.mean(cv_scores))
print("Test Set Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:686: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# <ipython-input-90-88c0fc7bc423>:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_classifier.fit(X_train, y_train)
# Cross-Validation Scores: [0.78125 0.77125 0.755   0.78    0.7775 ]
# Mean CV Score: 0.773
# Test Set Score: 0.7855

# %%
duplicates = test_data[test_data.duplicated()]

print("Duplicate Rows:")
print(duplicates)
# Out:
# Duplicate Rows:
# Empty DataFrame
# Columns: [HA_Open, HA_High, HA_Low, HA_Close, target, rsi2, rsi4, rsi8, rsi14, rsi21, stochastic_K5, stochastic_D5, stochastic_K14, stochastic_D14, stochastic_K21, stochastic_D21, MACD12, Signal12, bb_upper_band, bb_middle_band, bb_lower_band, EMA5, EMA10, EMA20, EMA50, EMA100, EMA200]
# Index: []
#
# [0 rows x 27 columns]

# %%
test_data.drop_duplicates(inplace=True)
# Out:
# <ipython-input-102-b467e46d8bc1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.drop_duplicates(inplace=True)

# %%
missing_values = test_data.isnull().sum()

print("Columns with Missing Values:")
print(missing_values[missing_values > 0])
# Out:
# Columns with Missing Values:
# Series([], dtype: int64)

# %%
test_data.dropna(inplace=True)
# Out:
# <ipython-input-104-74eb6c2c2c26>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.dropna(inplace=True)

# %%
# Make predictions on the test dataset
X_test_data=test_data.drop(['target'],axis=1)
y_test_data=test_data[['target']]

y_pred = rf_classifier.predict(X_test_data)

# Calculate accuracy
accuracy = accuracy_score(y_test_data, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.24193548387096775
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
